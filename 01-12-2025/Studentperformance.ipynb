# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
df=pd.read_csv("C:/Users/ABHILASH/Downloads/StudentsPerformance.csv")

# %%
df.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
len(df['gender'].unique())
# Out:
# 2

# %%
df['gender'].unique()
# Out:
# array(['female', 'male'], dtype=object)

# %%
len(df['gender'])
# Out:
# 1000

# %%
df.gender.value_counts()
# Out:
# gender
# female    518
# male      482
# Name: count, dtype: int64

# %%
df1=pd.get_dummies(df['gender'],dtype=int,prefix='gender',drop_first=True)
df1
# Out:
#      gender_male
# 0              0
# 1              0
# 2              0
# 3              1
# 4              1
# ..           ...
# 995            0
# 996            1
# 997            0
# 998            0
# 999            0
#
# [1000 rows x 1 columns]

# %%
df
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
df=pd.concat([df,df1],axis=1).drop(['gender'],axis=1)
df
# Out:
#     race/ethnicity parental level of education         lunch  \
# 0          group B           bachelor's degree      standard
# 1          group C                some college      standard
# 2          group B             master's degree      standard
# 3          group A          associate's degree  free/reduced
# 4          group C                some college      standard
# ..             ...                         ...           ...
# 995        group E             master's degree      standard
# 996        group C                 high school  free/reduced
# 997        group C                 high school  free/reduced
# 998        group D                some college      standard
# 999        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# 0                      none          72             72             74
# 1                 completed          69             90             88
# ...

# %%
len(df['race/ethnicity'].unique())
# Out:
# 5

# %%
df['race/ethnicity'].unique()
# Out:
# array(['group B', 'group C', 'group A', 'group D', 'group E'],
#       dtype=object)

# %%
len(df['race/ethnicity'])
# Out:
# 1000

# %%
df1=pd.get_dummies(df['race/ethnicity'],dtype=int,prefix='race/ethnicity',drop_first=True)
df1
# Out:
#      race/ethnicity_group B  race/ethnicity_group C  race/ethnicity_group D  \
# 0                         1                       0                       0
# 1                         0                       1                       0
# 2                         1                       0                       0
# 3                         0                       0                       0
# 4                         0                       1                       0
# ..                      ...                     ...                     ...
# 995                       0                       0                       0
# 996                       0                       1                       0
# 997                       0                       1                       0
# 998                       0                       0                       1
# 999                       0                       0                       1
#
#      race/ethnicity_group E
# ...

# %%
df=pd.concat([df,df1],axis=1).drop(['race/ethnicity'],axis=1)
df
# Out:
#     parental level of education         lunch test preparation course  \
# 0             bachelor's degree      standard                    none
# 1                  some college      standard               completed
# 2               master's degree      standard                    none
# 3            associate's degree  free/reduced                    none
# 4                  some college      standard                    none
# ..                          ...           ...                     ...
# 995             master's degree      standard               completed
# 996                 high school  free/reduced                    none
# 997                 high school  free/reduced               completed
# 998                some college      standard               completed
# 999                some college  free/reduced                    none
#
#      math score  reading score  writing score  gender_male  \
# 0            72             72             74            0
# ...

# %%
len(df['parental level of education'].unique())
# Out:
# 6

# %%
df['parental level of education'].unique()
# Out:
# array(["bachelor's degree", 'some college', "master's degree",
#        "associate's degree", 'high school', 'some high school'],
#       dtype=object)

# %%
df1=pd.get_dummies(df['parental level of education'],dtype=int,prefix='parental level of education',drop_first=True)
df1
# Out:
#      parental level of education_bachelor's degree  \
# 0                                                1
# 1                                                0
# 2                                                0
# 3                                                0
# 4                                                0
# ..                                             ...
# 995                                              0
# 996                                              0
# 997                                              0
# 998                                              0
# 999                                              0
#
#      parental level of education_high school  \
# 0                                          0
# 1                                          0
# 2                                          0
# 3                                          0
# 4                                          0
# ..                                       ...
# ...

# %%
df=pd.concat([df,df1],axis=1).drop(['parental level of education'],axis=1)
df
# Out:
#             lunch test preparation course  math score  reading score  \
# 0        standard                    none          72             72
# 1        standard               completed          69             90
# 2        standard                    none          90             95
# 3    free/reduced                    none          47             57
# 4        standard                    none          76             78
# ..            ...                     ...         ...            ...
# 995      standard               completed          88             99
# 996  free/reduced                    none          62             55
# 997  free/reduced               completed          59             71
# 998      standard               completed          68             78
# 999  free/reduced                    none          77             86
#
#      writing score  gender_male  race/ethnicity_group B  \
# 0               74            0                       1
# ...

# %%
len(df['lunch'].unique())
# Out:
# 2

# %%
df['lunch'].unique()
# Out:
# array(['standard', 'free/reduced'], dtype=object)

# %%
len(df['lunch'])
# Out:
# 1000

# %%
df.lunch.value_counts()
# Out:
# lunch
# standard        645
# free/reduced    355
# Name: count, dtype: int64

# %%
df1=pd.get_dummies(df['lunch'],dtype=int,prefix='lunch',drop_first=True)
df1
# Out:
#      lunch_standard
# 0                 1
# 1                 1
# 2                 1
# 3                 0
# 4                 1
# ..              ...
# 995               1
# 996               0
# 997               0
# 998               1
# 999               0
#
# [1000 rows x 1 columns]

# %%
df=pd.concat([df,df1],axis=1).drop(['lunch'],axis=1)
df
# Out:
#     test preparation course  math score  reading score  writing score  \
# 0                      none          72             72             74
# 1                 completed          69             90             88
# 2                      none          90             95             93
# 3                      none          47             57             44
# 4                      none          76             78             75
# ..                      ...         ...            ...            ...
# 995               completed          88             99             95
# 996                    none          62             55             55
# 997               completed          59             71             65
# 998               completed          68             78             77
# 999                    none          77             86             86
#
#      gender_male  race/ethnicity_group B  race/ethnicity_group C  \
# ...

# %%
len(df['test preparation course'].unique())
# Out:
# 2

# %%
df['test preparation course'].unique()
# Out:
# array(['none', 'completed'], dtype=object)

# %%
df1=pd.get_dummies(df['test preparation course'],dtype=int,prefix='test preparation course',drop_first=True)
df1
# Out:
#      test preparation course_none
# 0                               1
# 1                               0
# 2                               1
# 3                               1
# 4                               1
# ..                            ...
# 995                             0
# 996                             1
# 997                             0
# 998                             0
# 999                             1
#
# [1000 rows x 1 columns]

# %%
df=pd.concat([df,df1],axis=1).drop(['test preparation course'],axis=1)
df
# Out:
#      math score  reading score  writing score  gender_male  \
# 0            72             72             74            0
# 1            69             90             88            0
# 2            90             95             93            0
# 3            47             57             44            1
# 4            76             78             75            1
# ..          ...            ...            ...          ...
# 995          88             99             95            0
# 996          62             55             55            1
# 997          59             71             65            0
# 998          68             78             77            0
# 999          77             86             86            0
#
#      race/ethnicity_group B  race/ethnicity_group C  race/ethnicity_group D  \
# 0                         1                       0                       0
# 1                         0                       1                       0
# ...

# %%
from sklearn.preprocessing import PowerTransformer
trans=PowerTransformer(method='yeo-johnson')

# %%
la_trans=trans.fit_transform(df[['math score']])
la_trans.shape
# Out:
# (1000, 1)

# %%
print("skewness: ",pd.Series(la_trans.reshape(1000,)).skew())
print("kurtosis: ",pd.Series(la_trans.reshape(1000,)).kurtosis())
# Out:
# skewness:  -0.019726540424282797
# kurtosis:  -0.13692749576539942

# %%
sns.histplot(la_trans)
# Out:
# <Axes: ylabel='Count'>
